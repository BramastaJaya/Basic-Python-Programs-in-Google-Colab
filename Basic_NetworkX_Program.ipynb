# %% [markdown]
# <a href="https://colab.research.google.com/github/BramastaJaya/Basic-Python-Programs-in-Google-Colab/blob/main/Basic_NetworkX_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
# <h1>Jurnal Praktikum Dasar Kecerdasan Artifisial</h1>
# <h3>Modul: Pengenalan <i>Library</i> NetowrkX</h3>
# </div>

# %%
# Fungsi pendukung untuk mencetak graf
def show_graph(G, pos=None, title='') :
    # Jika posisi tidak ditentukan dari parameter maka akan generate posisi baru
    if pos == None :
        # Variabel pos yang menyimpat koordinat penempatan node
        pos = nx.spring_layout(G)

    # Plot graf G yang diberikan pada parameter
    nx.draw(
        G,
        pos,
        with_labels=True,
        node_color="red",
        node_size=2000,
        font_color="white",
        font_weight="bold",
        width=5
    )

    # Mengambil setiap weight dari setiap edge pada graf G
    edge_labels = nx.get_edge_attributes(G, "weight")

    # Menggambar weight dari edge pada visualisasi
    nx.draw_networkx_edge_labels(
        G,
        pos,
        edge_labels=edge_labels,
        font_color="blue",
        font_weight="bold",
        font_size=12
    )

    # Menambahkan margin pada setiap sisi
    plt.margins(0.2)
    # Menambahkan judul sesuai yang diberikan oleh parameter
    plt.title(title)
    # Menampilkan visualisasi graf pada terminal
    plt.show()

# %% [markdown]
# ### Import *Library* NetworkX dan Matplotlib
#
# *Library* Matplotlib digunakan untuk membantu menampilkan visualisasi graf pada terminal.

# %%
import networkx as nx # Import library NetworkX
import matplotlib.pyplot as plt # Import library Matplotlib

# %% [markdown]
# ### 1. *Undirected Graph* pada NetworkX (Bobot Nilai: `30`)

# %% [markdown]
# #### **!! Tidak usah dimodifikasi !!**

# %%
# Posisi untuk undirected graph agar sesuai dengan contoh soal
pos = {
    "A": (0, 1),
    "B": (1, 2),
    "C": (1, 0),
    "D": (2, 1),
    "E": (3, 1),
}

# %% [markdown]
# **a.** Inisalisasi graf tidak berarah pada NetworkX, kemudian tampilkan graf tersebut dengan menggunakan fungsi bantuan `show_graph`

# %%
# Inisialisasi undirected graph
G_undirected = nx.Graph()

# Cetak graf
show_graph(G_undirected, title="Undirected Graph Kosong")

# %% [markdown]
# Contoh *output*:

# %% [markdown]
# ![Undirected Graph Kosong](./asset/1_empty_undirected_graph.png)

# %% [markdown]
# **b.** Tambahkan *node* `A`, `B`, `C`, `D`, dan `E` pada graf, dan cetak graf dengan posisi `pos` yang sudah didefinisiakn
#
# Tip:
#
# Penambahan *node* pada graf dapat menggunakan `.add_nodes_from()` atau `.add_node()`

# %%
# Tambahkan node A, B, C, D, dan E pada graf
G_undirected.add_nodes_from(['A','B','C','D','E'])

# Tampilkan graf menggunakan posisi yang sudah ditentukan
show_graph(G_undirected, pos=pos, title="Menambahkan Node pada Undirected Graph")

# %% [markdown]
# Contoh *output*:
#
# ![Tambah node pada Undirected Graph](./asset/2_add_node_undirected_graph.png)

# %% [markdown]
# **c.** Tambahkan *edge* pada graf sebagai berikut:
# - A - B
# - A - C
# - B - D
# - C - D
# - D - E
#
# Tip :
# Pada *undirected graph*, *edge* A - B sama seperti *edge* B - A. Penambahan *edge* pada graf dapat menggunakan `.add_edge()` atau `.add_edges_from()`

# %%
# Tambahkan edge seperti soal diatas
G_undirected.add_edges_from([('A','B'),('A','C'),('B','D'),('C','D'),('D','E')])

# Tampilkan graf menggunakan posisi yang sudah ditentukan
show_graph(G_undirected, pos=pos, title="Menambahkan Edge pada Undirected Graph")

# %% [markdown]
# Contoh *output*:
#
# ![Menambahkan edge pada graf](./asset/3_add_edge_undirected_graph.png)

# %% [markdown]
# **d.** Cetak elemen pada graf yang terdiri dari
# - Daftar semua *node* yang terdapat dalam graf
# - Daftar semua *edge* yang terdapat dalam graf
# - Daftar tentangga pada setiap *node* dalam graf
# - Nilai derajat setiap *node* dalam graf

# %%
print("Node yang terdapat pada Graf")
print("\nNumber of nodes: ",G_undirected.nodes()) # Cetak list node dalam graf

print("\nEdge yang terdapat pada graf")
print("Number of edges: ",G_undirected.edges) # Cetak list edge dalam graf

print("\nTetangga Setiap Node dalam G")
for node in G_undirected.nodes():
    adj = list(G_undirected.adj[node])
    print("Number of Neightboor: ", node, "bertetangga dengan ", adj ) # Cetak daftar tetangga dari setiap node

print("\nDerajat G")
for node, degree in G_undirected.degree():
    print("Node ", node," memiliki derajat", degree)# Cetak derajat dari setiap node
# Out:
# Node yang terdapat pada Graf
#
# Number of nodes:  ['A', 'B', 'D', 'E', 'C']
#
# Edge yang terdapat pada graf
# Number of edges:  [('A', 'B'), ('A', 'C'), ('B', 'D'), ('D', 'E'), ('D', 'C')]
#
# Tetangga Setiap Node dalam G
# Number of Neightboor:  A bertetangga dengan  ['B', 'C']
# Number of Neightboor:  B bertetangga dengan  ['A', 'D']
# Number of Neightboor:  D bertetangga dengan  ['B', 'E', 'C']
# Number of Neightboor:  E bertetangga dengan  ['D']
# Number of Neightboor:  C bertetangga dengan  ['A', 'D']
#
# Derajat G
# Node  A  memiliki derajat 2
# Node  B  memiliki derajat 2
# Node  D  memiliki derajat 3
# Node  E  memiliki derajat 1
# Node  C  memiliki derajat 2

# %% [markdown]
# Contoh *output*:
#
# ```
# Node yang terdapat pada Graf
# ['A', 'B', 'C', 'D', 'E']
#
# Edge yang terdapat pada graf
# [('A', 'B'), ('A', 'C'), ('B', 'D'), ('C', 'D'), ('D', 'E')]
#
# Tetangga Setiap Node dalam G
# Tetangga A: ['B', 'C']
# Tetangga B: ['A', 'D']
# Tetangga C: ['A', 'D']
# Tetangga D: ['B', 'C', 'E']
# Tetangga E: ['D']
#
# Derajat G
# Derajat A: 2
# Derajat B: 2
# Derajat C: 2
# Derajat D: 3
# Derajat E: 1
# ```

# %% [markdown]
# **e.** Hapus *edge* C - D dari graf G

# %%
# Hapus edge C-D dari graf G
G_undirected.remove_edge("C","D")

# Cetak graf
show_graph(G_undirected, pos, title="Penghapusan edge C - D pada graf") # Gunakan title "Penghapusan Edge C - D pada Graf"

# %% [markdown]
# Contoh *output*:
#
# ![Hapus edge C-D dari graf](./asset/4_remove_edge_undirected_graph.png)

# %% [markdown]
# **f.** Hapus *node* C dari graf G

# %%
# Hapus node C dari graf G
G_undirected.remove_node("C")

# Cetak graf
show_graph(G_undirected, title="Graf Setelah Penghapusan Node C")# Gunakan title "Penghapusan Node C pada Graf"

# %% [markdown]
# Contoh *output*:
#
# ![Hapus node C dari Graf](./asset/5_remove_node_undirected_graph.png)

# %% [markdown]
# ### 2. *Directed Graph* pada NetworkX (Bobot Nilai: `30`)

# %% [markdown]
# ### **!! Tidak usah dimodifikasi !!**

# %%
# Posisi untuk directed grtaph agar sesuai dengan contoh soal
pos = {
    "A": (0, 1),
    "B": (1, 2),
    "C": (1, 0),
    "D": (2, 1),
    "E": (3, 1),
}

# %% [markdown]
# **a.** Inisialisasi graf berarah pada NetworkX, kemudian tampilkan graf tersebut dengan menggunakan fungsi bantuan `show_graph`

# %%
# Inisialisasi directed graph
G = nx.DiGraph()

# Cetak graf
show_graph(G, title="Directed Graph Kosong")

# %% [markdown]
# Contoh *output*:
#
# ![Directed Graph Kosong](./asset/6_empty_directed_graph.png)

# %% [markdown]
# **b.** Tambahkan *node* `A`, `B`, `C`, `D`, dan `E` pada graf, dan cetak graf dengan posisi `pos` yang sudah didefinisiakn
#
# Tip:
#
# Penambahan *node* pada graf dapat menggunakan `.add_nodes_from()` atau `.add_node()`

# %%
# Tambahkan node A, B, C, D, dan E pada graf
G.add_nodes_from(['A','B','C','D','E'])

# Tampilkan graf menggunakan posisi yang sudah ditentukan
show_graph(G, pos=pos, title="Menambahkan Node pada Undirected Graph")

# %% [markdown]
# Contoh *output*:
#
# ![Tambah node pada Directed Graph](./asset/7_add_node_directed_graph.png)

# %% [markdown]
# **c.** Tambahkan *edge* pada graf sebagai berikut:
# - A - B
# - A - C
# - D - B
# - C - D
# - D - E
#
# Tip :
# Pada *undirected graph*, *edge* A - B sama seperti *edge* B - A. Penambahan *edge* pada graf dapat menggunakan `.add_edge()` atau `.add_edges_from()`

# %%
# Tambahkan edge seperti soal diatas
G.add_edges_from([("A", "B"), ("A", "C"), ("D", "B"), ("C", "D"), ("D", "E")])

# Tampilkan graf menggunakan posisi yang sudah ditentukan
show_graph(G, pos=pos, title="Menambahkan Edge pada Directed Graph")

# %% [markdown]
# Contoh *output*:
#
# ![Menambahkan edge pada graf](./asset/8_add_edge_directed_graph.png)

# %% [markdown]
# **d.** Cetak elemen pada graf yang terdiri dari
# - Daftar semua *node* yang terdapat dalam graf
# - Daftar semua *edge* yang terdapat dalam graf
# - Daftar tentangga pada setiap *node* dalam graf
# - Nilai derajat setiap *node* dalam graf
# - Nilai derajat masuk (*In-Degree*) setiap *node* dalam graf
# - Nilai derajat keluar (*Out-Degree*) setiap *node* dalam graf

# %%
print("Node yang terdapat pada Graf")
print(list(G.nodes))

print("\nEdge yang terdapat pada graf")
print(list(G.edges))

print("\nTetangga Setiap Node dalam G")
for node in G.nodes:
    print(f"Tetangga {node}: {list(G.neighbors(node))}")

print("\nDerajat G")
for node, degree in G.degree():
    print(f"Derajat {node}: {degree}")

print("\nIn-degree node G")
for node, in_degree in G.in_degree():
    print(f"In-Degree {node}: {in_degree}")

print("\nOut-degree node G")
for node, out_degree in G.out_degree():
    print(f"Out-degree {node}: {out_degree}")
# Out:
# Node yang terdapat pada Graf
# ['A', 'B', 'C', 'D', 'E']
#
# Edge yang terdapat pada graf
# [('A', 'B'), ('A', 'C'), ('C', 'D'), ('D', 'B'), ('D', 'E')]
#
# Tetangga Setiap Node dalam G
# Tetangga A: ['B', 'C']
# Tetangga B: []
# Tetangga C: ['D']
# Tetangga D: ['B', 'E']
# Tetangga E: []
#
# Derajat G
# Derajat A: 2
# Derajat B: 2
# Derajat C: 2
# Derajat D: 3
# Derajat E: 1
#
# In-degree node G
# In-Degree A: 0
# In-Degree B: 2
# In-Degree C: 1
# In-Degree D: 1
# In-Degree E: 1
#
# Out-degree node G
# Out-degree A: 2
# Out-degree B: 0
# Out-degree C: 1
# Out-degree D: 2
# Out-degree E: 0

# %% [markdown]
# Contoh *output*:
#
# ```
# Node yang terdapat pada Graf
# ['A', 'B', 'C', 'D', 'E']
#
# Edge yang terdapat pada graf
# [('A', 'B'), ('A', 'C'), ('C', 'D'), ('D', 'B'), ('D', 'E')]
#
# Tetangga Setiap Node dalam G
# Tetangga A: ['B', 'C']
# Tetangga B: []
# Tetangga C: ['D']
# Tetangga D: ['B', 'E']
# Tetangga E: []
#
# Derajat G
# Derajat A: 2
# Derajat B: 2
# Derajat C: 2
# Derajat D: 3
# Derajat E: 1
#
# In-degree node G
# In-degree A: 0
# In-degree B: 2
# In-degree C: 1
# In-degree D: 1
# In-degree E: 1
#
# Out-degree node G
# Out-degree A: 2
# Out-degree B: 0
# Out-degree C: 1
# Out-degree D: 2
# Out-degree E: 0
# ```

# %% [markdown]
# **e.** Hapus *edge* C - D dari graf G

# %%
# Hapus edge C-D dari graf G
if G.has_edge("C", "D"):
    G.remove_edge("C", "D")

# Cetak graf
show_graph(G, title="Penghapusan Edge C - D pada Graf", pos=pos)

# %% [markdown]
# Contoh *output*:
#
# ![Hapus edge C-D dari graf](./asset/9_remove_edge_directed_graph.png)

# %% [markdown]
# **f.** Hapus *node* C dari graf G

# %%
# Hapus node C dari graf G
if "C" in G:
    G.remove_node("C")

# Cetak graf
show_graph(G, title="Penghapusan Node C Graf", pos=pos)

# %% [markdown]
# Contoh output:
#
# ![Hapus node C dari Graf](./asset/10_remove_node_directed_graph.png)

# %% [markdown]
# ### 3. Graf Berbobot (Bobot Nilai: `40`)

# %% [markdown]
# #### **!! Tidak usah diubah !!**

# %%
# Posisi untuk undirected graph agar sesuai dengan contoh soal
pos = {
    "A": (0, 1),
    "B": (1, 2),
    "C": (1, 0),
    "D": (2, 1),
    "E": (3, 1),
}

# %% [markdown]
# Buat graf berarah yang diberi bobot pada *edge* seperti gambar di bawah menggunakan `pos` yang sudah diberikan pada contoh *output* di bawah.

# %%
import networkx as nx
import matplotlib.pyplot as plt
bobot = [
    ('B', 'A', 7),
    ('A', 'C', 1),
    ('B', 'D', 18),
    ('D', 'C', 102),
    ('E', 'D', 52)
]

G = nx.DiGraph()
G.add_nodes_from(['A', 'B', 'C', 'D', 'E'])

G.add_weighted_edges_from(bobot)

plt.figure(figsize=(6, 5))
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='red', font_size=14,font_color='white', edge_color='black', width=3, arrowsize=20)

edge_labels = {(u, v): d for u, v, d in G.edges(data='weight')}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=12, font_color='blue')

plt.title("Bentuk DiGraf dengan edge yang Bobot")
plt.show()

# %% [markdown]
# Contoh *output* :
#
# ![Contoh soal no.3](./asset/11_contoh_soal_3.png)
